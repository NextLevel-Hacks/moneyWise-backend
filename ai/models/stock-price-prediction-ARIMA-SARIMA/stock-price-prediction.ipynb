# %%
# !pip install pmdarima
# !pip install statsmodels
# Out:
# Requirement already satisfied: pmdarima in c:\python312\lib\site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in c:\python312\lib\site-packages (from pmdarima) (1.1.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\python312\lib\site-packages (from pmdarima) (3.0.11)
# Requirement already satisfied: numpy>=1.21.2 in c:\python312\lib\site-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in c:\python312\lib\site-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in c:\python312\lib\site-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\python312\lib\site-packages (from pmdarima) (1.13.0)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\python312\lib\site-packages (from pmdarima) (0.14.4)
# Requirement already satisfied: urllib3 in c:\python312\lib\site-packages (from pmdarima) (1.26.18)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\python312\lib\site-packages (from pmdarima) (75.8.0)
# Requirement already satisfied: packaging>=17.1 in c:\python312\lib\site-packages (from pmdarima) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python312\lib\site-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\python312\lib\site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\python312\lib\site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Collecting joblib>=0.11 (from pmdarima)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python312\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.4.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\python312\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (1.0.1)
# Requirement already satisfied: six>=1.5 in c:\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.19->pmdarima) (1.16.0)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Installing collected packages: joblib
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.1
#     Uninstalling joblib-1.1.1:
#       Successfully uninstalled joblib-1.1.1
# Successfully installed joblib-1.4.2
# WARNING: Ignoring invalid distribution ~harset-normalizer (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ttpx (C:\Python312\Lib\site-packages)
# DEPRECATION: Loading egg at c:\python312\lib\site-packages\vboxapi-1.0-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Ignoring invalid distribution ~harset-normalizer (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ttpx (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~harset-normalizer (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ttpx (C:\Python312\Lib\site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: statsmodels in c:\python312\lib\site-packages (0.14.4)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\python312\lib\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\python312\lib\site-packages (from statsmodels) (1.13.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\python312\lib\site-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\python312\lib\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\python312\lib\site-packages (from statsmodels) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python312\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\python312\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\python312\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.16.0)
# WARNING: Ignoring invalid distribution ~harset-normalizer (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ttpx (C:\Python312\Lib\site-packages)
# DEPRECATION: Loading egg at c:\python312\lib\site-packages\vboxapi-1.0-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Ignoring invalid distribution ~harset-normalizer (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ttpx (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~harset-normalizer (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ttpx (C:\Python312\Lib\site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install prophet
# !pip install pandas-profiling
# Out:
# Requirement already satisfied: prophet in c:\python312\lib\site-packages (1.1.6)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\python312\lib\site-packages (from prophet) (1.2.5)
# Requirement already satisfied: numpy>=1.15.4 in c:\python312\lib\site-packages (from prophet) (1.26.4)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\python312\lib\site-packages (from prophet) (3.9.2)
# Requirement already satisfied: pandas>=1.0.4 in c:\python312\lib\site-packages (from prophet) (2.2.2)
# Requirement already satisfied: holidays<1,>=0.25 in c:\python312\lib\site-packages (from prophet) (0.69)
# Requirement already satisfied: tqdm>=4.36.1 in c:\python312\lib\site-packages (from prophet) (4.66.2)
# Requirement already satisfied: importlib-resources in c:\python312\lib\site-packages (from prophet) (6.5.2)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in c:\python312\lib\site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in c:\python312\lib\site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python312\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\python312\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python312\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python312\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\python312\lib\site-packages (from matplotlib>=2.0.0->prophet) (24.0)
# Requirement already satisfied: pillow>=8 in c:\python312\lib\site-packages (from matplotlib>=2.0.0->prophet) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python312\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.1.4)
# Requirement already satisfied: pytz>=2020.1 in c:\python312\lib\site-packages (from pandas>=1.0.4->prophet) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\python312\lib\site-packages (from pandas>=1.0.4->prophet) (2024.1)
# Requirement already satisfied: colorama in c:\python312\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\python312\lib\site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.16.0)
# WARNING: Ignoring invalid distribution ~harset-normalizer (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ttpx (C:\Python312\Lib\site-packages)
# DEPRECATION: Loading egg at c:\python312\lib\site-packages\vboxapi-1.0-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Ignoring invalid distribution ~harset-normalizer (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ttpx (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~harset-normalizer (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ttpx (C:\Python312\Lib\site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting pandas-profiling
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting joblib~=1.1.0 (from pandas-profiling)
#   Using cached joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: scipy>=1.4.1 in c:\python312\lib\site-packages (from pandas-profiling) (1.13.0)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\python312\lib\site-packages (from pandas-profiling) (2.2.2)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\python312\lib\site-packages (from pandas-profiling) (3.9.2)
# Requirement already satisfied: pydantic>=1.8.1 in c:\python312\lib\site-packages (from pandas-profiling) (2.5.3)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\python312\lib\site-packages (from pandas-profiling) (6.0.1)
# Requirement already satisfied: jinja2>=2.11.1 in c:\python312\lib\site-packages (from pandas-profiling) (3.1.3)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\python312\lib\site-packages (from pandas-profiling) (2.1.5)
# Collecting visions==0.7.4 (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Using cached visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\python312\lib\site-packages (from pandas-profiling) (1.26.4)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\python312\lib\site-packages (from pandas-profiling) (0.1.12)
# Collecting missingno>=0.4.2 (from pandas-profiling)
#   Using cached missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Collecting phik>=0.11.1 (from pandas-profiling)
#   Using cached phik-0.12.4-cp312-cp312-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in c:\python312\lib\site-packages (from pandas-profiling) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in c:\python312\lib\site-packages (from pandas-profiling) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.2 in c:\python312\lib\site-packages (from pandas-profiling) (4.66.2)
# Requirement already satisfied: seaborn>=0.10.1 in c:\python312\lib\site-packages (from pandas-profiling) (0.13.2)
# Requirement already satisfied: multimethod>=1.4 in c:\python312\lib\site-packages (from pandas-profiling) (2.0)
# Requirement already satisfied: attrs>=19.3.0 in c:\python312\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (23.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\python312\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (3.4.2)
# Requirement already satisfied: imagehash in c:\python312\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (4.3.2)
# Requirement already satisfied: Pillow in c:\python312\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (10.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python312\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\python312\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python312\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python312\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\python312\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python312\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python312\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\python312\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\python312\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\python312\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\python312\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\python312\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python312\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\python312\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python312\lib\site-packages (from requests>=2.24.0->pandas-profiling) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python312\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2024.2.2)
# Requirement already satisfied: colorama in c:\python312\lib\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in c:\python312\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.8.0)
# Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# Using cached joblib-1.1.1-py2.py3-none-any.whl (309 kB)
# Using cached missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Using cached phik-0.12.4-cp312-cp312-win_amd64.whl (666 kB)
# Installing collected packages: joblib, visions, phik, missingno, pandas-profiling
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.2
#     Uninstalling joblib-1.4.2:
#       Successfully uninstalled joblib-1.4.2
# WARNING: Ignoring invalid distribution ~harset-normalizer (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ttpx (C:\Python312\Lib\site-packages)
# DEPRECATION: Loading egg at c:\python312\lib\site-packages\vboxapi-1.0-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Ignoring invalid distribution ~harset-normalizer (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ttpx (C:\Python312\Lib\site-packages)
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 2] The system cannot find the file specified: 'C:\\Python312\\Scripts\\pandas_profiling.exe' -> 'C:\\Python312\\Scripts\\pandas_profiling.exe.deleteme'
#
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from prophet import Prophet
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima_model import ARIMA
from pmdarima.arima import auto_arima
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
# Out:
# Importing plotly failed. Interactive plots will not work.

# %% [markdown]
# # Data Import and Preprocessing

# %%
#Import the dataset
data = pd.read_csv(r'./NSE-TATAGLOBAL.csv')
data.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
data['Date'] = pd.to_datetime(data.Date,format='%Y-%m-%d')

# %%
#Reverse the order of the dataset so that the latest year data will arrive in the tail of the dataframe
data = data.iloc[::-1]

# %%
#View the dataset
data.head(20)
# Out:
#            Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 2034 2010-07-21  122.10  123.00  121.05  121.10  121.55                658666
# 2033 2010-07-22  120.30  122.00  120.25  120.75  120.90                293312
# 2032 2010-07-23  121.80  121.95  120.25  120.35  120.65                281312
# 2031 2010-07-26  120.10  121.00  117.10  117.10  117.60                658440
# 2030 2010-07-27  117.60  119.50  112.00  118.80  118.65                586100
# 2029 2010-07-28  118.00  120.50  117.20  118.15  118.25                835593
# 2028 2010-07-29  112.50  121.70  112.50  117.50  116.60               2359134
# 2027 2010-07-30  116.50  118.00  114.60  115.85  116.05               2656191
# 2026 2010-08-02  117.30  118.50  116.60  118.10  117.30                663593
# 2025 2010-08-03  118.30  119.95  117.90  118.65  118.30                611234
# 2024 2010-08-04  118.50  119.00  116.10  116.65  116.50               1012396
# 2023 2010-08-05  117.00  117.00  113.80  114.10  114.05                777490
# 2022 2010-08-06  114.10  114.90  111.75  112.20  112.10                547881
# 2021 2010-08-09  112.00  113.85  112.00  113.20  112.85                415026
# 2020 2010-08-10  112.90  114.30  111.55  112.05  112.30                327364
# 2019 2010-08-11  113.75  115.50  112.00  113.90  113.90               1307966
# 2018 2010-08-12  113.00  114.45  112.25  112.80  112.55                434265
# 2017 2010-08-13  113.40  116.00  112.60  114.10  114.15                755675
# 2016 2010-08-16  115.95  115.95  110.75  112.00  111.25                818831
# 2015 2010-08-17  111.90  112.40  109.70  110.20  110.10               1079479
#
#       Turnover (Lacs)
# 2034           803.56
# 2033           355.17
# 2032           340.31
# 2031           780.01
# 2030           694.98
# 2029           994.01
# 2028          2791.03
# 2027          3112.68
# 2026           779.85
# 2025           726.78
# 2024          1184.49
# 2023           893.61
# 2022           620.33
# 2021           468.60
# 2020           368.92
# 2019          1499.66
# 2018           492.18
# 2017           868.71
# 2016           919.52
# 2015          1196.57

# %%
data.isnull().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
data.dtypes
# Out:
# Date                    datetime64[ns]
# Open                           float64
# High                           float64
# Low                            float64
# Last                           float64
# Close                          float64
# Total Trade Quantity             int64
# Turnover (Lacs)                float64
# dtype: object

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### From the overview above, we can see that the data is clean and does not need any serious cleaning. There are no missing values or any duplicate. Let us move forward

# %%
#Use date column as the index
data.reset_index(inplace=True)

# %%
data.head()
# Out:
#    index       Date   Open    High     Low    Last   Close  \
# 0   2034 2010-07-21  122.1  123.00  121.05  121.10  121.55
# 1   2033 2010-07-22  120.3  122.00  120.25  120.75  120.90
# 2   2032 2010-07-23  121.8  121.95  120.25  120.35  120.65
# 3   2031 2010-07-26  120.1  121.00  117.10  117.10  117.60
# 4   2030 2010-07-27  117.6  119.50  112.00  118.80  118.65
#
#    Total Trade Quantity  Turnover (Lacs)
# 0                658666           803.56
# 1                293312           355.17
# 2                281312           340.31
# 3                658440           780.01
# 4                586100           694.98

# %%
#Plot all the variables against the Date and check for the relationships, patterns and trends
for column in data.columns[2:]:
    plt.figure(figsize=(6,4 ))
    plt.plot(data['Date'], data[column])
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} vs. Date')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### From above plot, it can be seen that the prices, turnover and total trade quantity is increasing from 2017

# %% [markdown]
# # Checking Stationarity

# %%
# Define a function which will give us rolling mean and standard deviation and perform ADF Test
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()
    
    #Plot rolling statistics:
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.show(block=False)
    
    print("Results of dickey fuller test")
    adft = adfuller(timeseries,autolag='AIC')
    
    # output for dft will give us without defining what the values are.
    #hence we manually write what values does it explains using a for loop
    
    output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key] =  values
    print(output)

# %%
test_stationarity(data['Open'])
# Out:
# Results of dickey fuller test
# Test Statistics                  -0.951734
# p-value                           0.770459
# No. of lags used                  8.000000
# Number of observations used    2026.000000
# critical value (1%)              -3.433582
# critical value (5%)              -2.862968
# critical value (10%)             -2.567530
# dtype: float64

# %% [markdown]
# Through the above graph, we can see the increasing mean and standard deviation and hence our series is not stationary.
#
# We see that the p-value is greater than 0.05 so we cannot reject the Null hypothesis. Also, the test statistics is greater than the critical values. so the data is non-stationary.
#
# In order to perform a time series analysis, we may need to separate seasonality and trend from our series. The resultant series will become stationary through this process.
#
# So let us separate Trend and Seasonality from the time series.

# %%
# Decompose the series to separate the trend and the seasonality from a time series, 
result = seasonal_decompose(data['Open'], model='multiplicative', period = 30)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(8, 5)

# %%
def test_stationarity(timeseries):
    
    # Transformation to make the data stationary
    timeseries_log = np.log(timeseries)
    timeseries_log_diff = timeseries_log.diff().dropna()

    # Determing rolling statistics
    rolmean = timeseries_log_diff.rolling(window=12).mean()
    rolstd = timeseries_log_diff.rolling(window=12).std()

    # Plot rolling statistics
    plt.figure(figsize=(6, 4))
    plt.plot(timeseries_log_diff, color='blue', label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.xlabel('Date')
    plt.ylabel('Log-Difference')
    plt.show()

    # Perform ADF test
    adft = adfuller(timeseries_log_diff, autolag='AIC')

    # Output the ADF test results
    output = pd.Series(adft[0:4], index=['Test Statistic', 'p-value', 'Number of Lags Used', 'Number of Observations Used'])
    for key, value in adft[4].items():
        output[f'Critical Value ({key})'] = value
    print(output)

# %%
test_stationarity(data['Open'])
# Out:
# Test Statistic                  -49.577189
# p-value                           0.000000
# Number of Lags Used               0.000000
# Number of Observations Used    2033.000000
# Critical Value (1%)              -3.433571
# Critical Value (5%)              -2.862963
# Critical Value (10%)             -2.567527
# dtype: float64

# %% [markdown]
# Based on the ADF test results above, the test statistic is significantly lower than the critical values at all levels of significance (1%, 5%, and 10%). Additionally, the p-value is very close to zero, indicating strong evidence against the null hypothesis of non-stationarity.
#
# Therefore, based on these results, we can conclude that the time series is stationary after the transformation.

# %% [markdown]
# # Model Fitting
# ## Moving Average

# %%
import numpy as np

def moving_avg_prediction(data):
    shape = data.shape[0]
    df_new = data[['Open']]
    df_new['Open'] = np.log(df_new['Open'])  # Apply logarithmic transformation
    
    train_set = df_new.iloc[:ceil(shape * 0.9)]
    valid_set = df_new.iloc[ceil(shape * 0.9):]
    
    print('-----------------------------------------------------------')
    print('-----------STOCK PRICE PREDICTION BY MOVING AVERAGE--------')
    print('-----------------------------------------------------------')
    print('Shape of Training Set:', train_set.shape)
    print('Shape of Validation Set:', valid_set.shape)
    
    preds = []
    for i in range(0, valid_set.shape[0]):
        a = train_set['Open'][len(train_set) - valid_set.shape[0] + i:].sum() + sum(preds)
        b = a / (valid_set.shape[0])
        preds.append(b)
    
    rms = np.sqrt(np.mean(np.power((np.array(valid_set['Open']) - preds), 2)))
    print('RMSE value on validation set:', rms)
    print('-----------------------------------------------------------')
    print('-----------------------------------------------------------')
    
    valid_set['Predictions'] = preds
    
    plt.figure(figsize=(6, 4))
    plt.plot(train_set['Open'])
    plt.plot(valid_set[['Open', 'Predictions']])
    plt.xlabel('Date', size=20)
    plt.ylabel('Log-transformed Open Price', size=20)
    plt.title('Log-transformed Open Price Prediction by Moving Averages', size=20)
    plt.legend(['Model Training Data', 'Actual Data', 'Predicted Data'])

# %%
from math import ceil, floor
moving_avg_prediction(data)
# Out:
# ----------------------------------------------------------
# -----------STOCK PRICE PREDICTION BY AUTO ARIMA-----------
# ----------------------------------------------------------
# Shape of Training Set: (1832, 1)
# Shape of Validation Set: (203, 1)
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-8692.066, Time=0.15 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-8710.004, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-8710.096, Time=0.30 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-8693.292, Time=0.20 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-8708.142, Time=0.30 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-8708.178, Time=0.37 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-8706.122, Time=0.90 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-8711.116, Time=0.09 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-8709.171, Time=0.11 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=-8709.170, Time=0.12 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=-8711.046, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-8707.072, Time=0.14 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 2.787 seconds
# RMSE value on validation set: 0.1138552459146161
# -----------------------------------------------------------
# -----------------------------------------------------------

# %% [markdown]
# ##### Interpretation: The RMSE value is close to 0.362 but the results are not that good (as we see from the plot).

# %% [markdown]
# ## ARIMA

# %%
def moving_avg_prediction(data):
    shape = data.shape[0]
    df_new = data[['Open']]
    df_new['Open'] = np.log(df_new['Open'])  # Apply logarithmic transformation
    
    train_set = df_new.iloc[:ceil(shape * 0.9)]
    valid_set = df_new.iloc[ceil(shape * 0.9):]
    print('----------------------------------------------------------')
    print('-----------STOCK PRICE PREDICTION BY AUTO ARIMA-----------')
    print('----------------------------------------------------------')
    print('Shape of Training Set:', train_set.shape)
    print('Shape of Validation Set:', valid_set.shape)
    training = train_set['Open']
    validation = valid_set['Open']
    model = auto_arima(training, start_p=0, start_q=0, max_p=3, max_q=3, start_P=0, seasonal=True, d=1, D=1, trace=True, error_action='ignore', suppress_warnings=True)
    model.fit(training)
    forecast = model.predict(n_periods=len(validation))
    forecast.index = validation.index
    forecast = pd.DataFrame(forecast,columns =['Prediction'])
    print(forecast)
    #forecast = pd.DataFrame(forecast, index=valid_set.index, columns=['Prediction'])
    rms = np.sqrt(np.mean(np.power((np.array(validation) - np.array(forecast['Prediction'])), 2)))
    print('RMSE value on validation set:', rms)
    print('-----------------------------------------------------------')
    print('-----------------------------------------------------------')
    
    plt.figure(figsize=(8, 4))
    plt.plot(train_set['Open'])
    plt.plot(valid_set['Open'])
    plt.plot(forecast['Prediction'])
    plt.xlabel('Date', size=20)
    plt.ylabel('Stock Price', size=20)
    plt.title('Stock Price Prediction by Auto ARIMA', size=20)
    plt.legend(['Model Training Data', 'Actual Data', 'Predicted Data'])

# %%
data.head()
# Out:
#    index       Date   Open    High     Low    Last   Close  \
# 0   2034 2010-07-21  122.1  123.00  121.05  121.10  121.55
# 1   2033 2010-07-22  120.3  122.00  120.25  120.75  120.90
# 2   2032 2010-07-23  121.8  121.95  120.25  120.35  120.65
# 3   2031 2010-07-26  120.1  121.00  117.10  117.10  117.60
# 4   2030 2010-07-27  117.6  119.50  112.00  118.80  118.65
#
#    Total Trade Quantity  Turnover (Lacs)
# 0                658666           803.56
# 1                293312           355.17
# 2                281312           340.31
# 3                658440           780.01
# 4                586100           694.98

# %%
data.set_index('Date',inplace=True)

# %%
data.head()
# Out:
#             index   Open    High     Low    Last   Close  \
# Date
# 2010-07-21   2034  122.1  123.00  121.05  121.10  121.55
# 2010-07-22   2033  120.3  122.00  120.25  120.75  120.90
# 2010-07-23   2032  121.8  121.95  120.25  120.35  120.65
# 2010-07-26   2031  120.1  121.00  117.10  117.10  117.60
# 2010-07-27   2030  117.6  119.50  112.00  118.80  118.65
#
#             Total Trade Quantity  Turnover (Lacs)
# Date
# 2010-07-21                658666           803.56
# 2010-07-22                293312           355.17
# 2010-07-23                281312           340.31
# 2010-07-26                658440           780.01
# 2010-07-27                586100           694.98

# %%
moving_avg_prediction(data)
# Out:
# ----------------------------------------------------------
# -----------STOCK PRICE PREDICTION BY AUTO ARIMA-----------
# ----------------------------------------------------------
# Shape of Training Set: (1832, 1)
# Shape of Validation Set: (203, 1)
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-8692.066, Time=0.17 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-8710.004, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-8710.096, Time=0.29 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-8693.292, Time=0.16 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-8708.142, Time=0.25 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-8708.178, Time=0.27 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-8706.122, Time=0.87 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-8711.116, Time=0.10 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=-8709.171, Time=0.12 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=-8709.170, Time=0.11 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=-8711.046, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=-8707.072, Time=0.14 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 2.598 seconds
#             Prediction
# Date
# 2017-12-05    5.653406
# 2017-12-06    5.653406
# 2017-12-07    5.653406
# 2017-12-08    5.653406
# 2017-12-11    5.653406
# ...                ...
# 2018-09-24    5.653406
# 2018-09-25    5.653406
# 2018-09-26    5.653406
# 2018-09-27    5.653406
# 2018-09-28    5.653406
#
# [203 rows x 1 columns]
# RMSE value on validation set: 0.1138552459146161
# -----------------------------------------------------------
# -----------------------------------------------------------
# C:\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %% [markdown]
# #### Interpretation: An auto ARIMA model uses past data to understand the pattern in the time series. Using these values, the model captured an increasing trend in the series. Although the predictions using this technique are far better than that of the previously implemented model, these predictions are close than previous moving average model.

# %% [markdown]
# # SARIMA

# %%
data.head()
# Out:
#             index   Open    High     Low    Last   Close  \
# Date
# 2010-07-21   2034  122.1  123.00  121.05  121.10  121.55
# 2010-07-22   2033  120.3  122.00  120.25  120.75  120.90
# 2010-07-23   2032  121.8  121.95  120.25  120.35  120.65
# 2010-07-26   2031  120.1  121.00  117.10  117.10  117.60
# 2010-07-27   2030  117.6  119.50  112.00  118.80  118.65
#
#             Total Trade Quantity  Turnover (Lacs)
# Date
# 2010-07-21                658666           803.56
# 2010-07-22                293312           355.17
# 2010-07-23                281312           340.31
# 2010-07-26                658440           780.01
# 2010-07-27                586100           694.98

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import ceil
from statsmodels.tsa.statespace.sarimax import SARIMAX

def sarima_prediction(data):
    shape = data.shape[0]
    df_new = data[['Open']]
    df_new['Open'] = np.log(df_new['Open'])  # Apply logarithmic transformation
    
    train_set = df_new.iloc[:ceil(shape * 0.9)]
    valid_set = df_new.iloc[ceil(shape * 0.9):]
    print('----------------------------------------------------------')
    print('-----------STOCK PRICE PREDICTION BY SARIMA--------------')
    print('----------------------------------------------------------')
    print('Shape of Training Set:', train_set.shape)
    print('Shape of Validation Set:', valid_set.shape)
    training = train_set['Open']
    validation = valid_set['Open']
    
    # Define and fit the SARIMA model
    model = SARIMAX(training, 
                    order=(1, 1, 1), # You may need to adjust these parameters
                    seasonal_order=(1, 1, 1, 12), # Adjust the seasonal_order as needed
                    enforce_stationarity=False,
                    enforce_invertibility=False)
    
    results = model.fit()
    
    # Forecast
    forecast = results.get_forecast(steps=len(validation))
    forecast_index = valid_set.index
    forecast_mean = forecast.predicted_mean
    forecast_conf_int = forecast.conf_int()
    
    forecast_df = pd.DataFrame(forecast_mean, index=forecast_index, columns=['Prediction'])
    print(forecast_df)
    
    # Calculate RMSE
    rms = np.sqrt(np.mean(np.power(validation - forecast_df['Prediction'], 2)))
    print('RMSE value on validation set:', rms)
    print('-----------------------------------------------------------')
    print('-----------------------------------------------------------')
    
    # Plotting
    plt.figure(figsize=(12, 6))
    plt.plot(train_set['Open'], label='Model Training Data')
    plt.plot(valid_set['Open'], label='Actual Data')
    plt.plot(forecast_df['Prediction'], label='Predicted Data', color='red')
    plt.fill_between(forecast_index, 
                     forecast_conf_int.iloc[:, 0], 
                     forecast_conf_int.iloc[:, 1], 
                     color='pink', alpha=0.3)
    plt.xlabel('Date', size=20)
    plt.ylabel('Stock Price', size=20)
    plt.title('Stock Price Prediction by SARIMA', size=20)
    plt.legend()
    plt.show()

# Example usage:
# data = pd.read_csv('your_data.csv', parse_dates=True, index_col='Date')
# sarima_prediction(data)

# %%
sarima_prediction(data)
# Out:
# ----------------------------------------------------------
# -----------STOCK PRICE PREDICTION BY SARIMA--------------
# ----------------------------------------------------------
# Shape of Training Set: (1832, 1)
# Shape of Validation Set: (203, 1)
#      Prediction
# 1832        NaN
# 1833        NaN
# 1834        NaN
# 1835        NaN
# 1836        NaN
# ...         ...
# 2030        NaN
# 2031        NaN
# 2032        NaN
# 2033        NaN
# 2034        NaN
#
# [203 rows x 1 columns]
# RMSE value on validation set: nan
# -----------------------------------------------------------
# -----------------------------------------------------------

# %%
data.head()
# Out:
#             index   Open    High     Low    Last   Close  \
# Date
# 2010-07-21   2034  122.1  123.00  121.05  121.10  121.55
# 2010-07-22   2033  120.3  122.00  120.25  120.75  120.90
# 2010-07-23   2032  121.8  121.95  120.25  120.35  120.65
# 2010-07-26   2031  120.1  121.00  117.10  117.10  117.60
# 2010-07-27   2030  117.6  119.50  112.00  118.80  118.65
#
#             Total Trade Quantity  Turnover (Lacs)
# Date
# 2010-07-21                658666           803.56
# 2010-07-22                293312           355.17
# 2010-07-23                281312           340.31
# 2010-07-26                658440           780.01
# 2010-07-27                586100           694.98
